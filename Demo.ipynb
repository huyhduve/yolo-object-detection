# %% [markdown]
# ## Initialization

# %%
from scripts.ObjectDetection import YOLODetector

# %%
detector = YOLODetector()
results = detector.detect(
    image_paths="example\images\image_1.webp",
    conf_threshold=0.6, 
    display_result=True,
    output_object_folder="example\output-objects",
    output_image_folder="example\output-labelled_images"
)
# Out:
# [INFO]: Displaying image with detections...
# [INFO]: Saving labelled image of image_4.webp to example\output-labelled_images
# [INFO]: Saving detected objects from image_4.webp
